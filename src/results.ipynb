# %% [markdown]
# # Imports

# %%
import pandas as pd
from qqman import qqman
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # GWAS Comparisons

# %% [markdown]
# ## Plink vs. Python

# %% [markdown]
# ### Plink GWAS Manhattan and QQ Plot

# %%
plink = pd.read_csv("../plink_results/ps3_gwas.assoc.linear", sep=r"\s+")
fig, (ax0, ax1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [2, 1]})
fig.set_size_inches((15, 5))
fig.suptitle("Plink GWAS Manhattan and QQ Plot", fontsize=16)
qqman.manhattan(plink, ax=ax0)
qqman.qqplot(plink, ax=ax1)

# %% [markdown]
# ### GWAS in Python Manhattan and QQ Plot

# %%
gwas_py = pd.read_csv("../python_results/gwas_results.tsv", sep=r"\s+")
fig, (ax0, ax1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [2, 1]})
fig.set_size_inches((15, 5))
fig.suptitle("GWAS in Python Manhattan and QQ Plot", fontsize=16)
qqman.manhattan(gwas_py, ax=ax0)
qqman.qqplot(gwas_py, ax=ax1)

# %% [markdown]
# ### Effect Size Comparison

# %%
merged = plink.merge(gwas_py, on="SNP", suffixes=("_plink", "_gwas_py"))
merged[["BETA_plink", "BETA_gwas_py"]].corr()

plt.scatter(merged["BETA_plink"], merged["BETA_gwas_py"], s=10)
plt.xlabel("PLINK Beta")
plt.ylabel("GWAS in Python Beta")
plt.title("Effect Size Comparison")
plt.show()

# %% [markdown]
# ### P-Value Comparison

# %%
merged["logP_plink"] = -np.log10(merged["P_plink"])
merged["logP_gwas_py"]  = -np.log10(merged["P_gwas_py"])

plt.scatter(merged["logP_plink"], merged["logP_gwas_py"], s=10)
plt.xlabel("-log10 P (PLINK)")
plt.ylabel("-log10 P (Gwas in Python)")
plt.title("P-value Comparison")
plt.show()

# %%
merged["rank_plink"] = merged["P_plink"].rank(method="min")
merged["rank_gwas_py"]  = merged["P_gwas_py"].rank(method="min")

merged[["rank_plink", "rank_gwas_py"]].corr()

top_plink = set(plink.nsmallest(10, "P")["SNP"])
top_gwas_py  = set(gwas_py.nsmallest(10, "P")["SNP"])

print("Overlap in Top 10:", len(top_plink & top_gwas_py))
# Out:
# Overlap in Top 10: 10

# %%
summary = merged[[
    "SNP",
    "BETA_plink", "BETA_gwas_py",
    "P_plink", "P_gwas_py",
    "rank_plink", "rank_gwas_py"
]].sort_values("rank_plink").head(20)

summary
# Out:
#                SNP  BETA_plink  BETA_gwas_py       P_plink     P_gwas_py  \
# 302263  rs62117204      2.1050      2.104528  2.122000e-32  2.121923e-32
# 302266   rs4803750      1.8980      1.898317  6.102000e-29  6.102444e-29
# 302262   rs1531517      1.0010      1.000888  2.328000e-15  2.327750e-15
# 833752   rs2519093     -0.9908     -0.990820  5.676000e-13  5.675715e-13
# 833754    rs507666     -0.9908     -0.990820  5.676000e-13  5.675715e-13
# 537173    rs358702     -0.5654     -0.565360  1.204000e-11  1.204200e-11
# 120646  rs11113551     -0.7108     -0.710799  3.291000e-11  3.290831e-11
# 537180   rs7636224     -0.5419     -0.541872  4.915000e-11  4.915194e-11
# 120635   rs2374725     -0.7102     -0.710158  8.035000e-11  8.035379e-11
# 120637  rs11113515     -0.6867     -0.686743  1.027000e-10  1.027314e-10
# 749192  rs13245385     -0.5247     -0.524654  2.125000e-10  2.125053e-10
# 120668  rs11113611     -0.6884     -0.688407  2.196000e-10  2.195618e-10
# 120689  rs11113710     -0.6932     -0.693186  3.700000e-10  3.699981e-10
# 392826   rs6069045     -0.5387     -0.538740  5.145000e-10  5.145065e-10
# 120693   rs4475967     -0.7242     -0.724178  6.259000e-10  6.258775e-10
# 463338   rs1037266     -0.5538     -0.553780  8.091000e-10  8.091219e-10
# 835477   rs3125787      0.5131      0.513087  8.171000e-10  8.170636e-10
# 120698  rs11113732     -0.7054     -0.705424  9.224000e-10  9.224072e-10
# 685092    rs597443     -0.5993     -0.599305  1.098000e-09  1.097611e-09
# 561479   rs4861120     -0.4589     -0.458938  1.297000e-09  1.296681e-09
#
#         rank_plink  rank_gwas_py
# 302263         1.0           1.0
# 302266         2.0           2.0
# 302262         3.0           3.0
# 833752         4.0           4.0
# 833754         4.0           4.0
# 537173         6.0           6.0
# 120646         7.0           7.0
# 537180         8.0           8.0
# 120635         9.0           9.0
# 120637        10.0          10.0
# 749192        11.0          11.0
# 120668        12.0          12.0
# 120689        13.0          13.0
# 392826        14.0          14.0
# 120693        15.0          15.0
# 463338        16.0          16.0
# 835477        17.0          17.0
# 120698        18.0          18.0
# 685092        19.0          19.0
# 561479        20.0          20.0

# %%
print("Beta correlation:", merged["BETA_plink"].corr(merged["BETA_gwas_py"]))
# Out:
# Beta correlation: 0.9999009533806519

# %% [markdown]
# ## Plink vs. Python w/Covariance

# %% [markdown]
# ### Plink GWAS Manhattan and QQ Plot

# %%
plink = pd.read_csv("../plink_results/ps3_gwas_covar.assoc.linear", sep=r"\s+")
fig, (ax0, ax1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [2, 1]})
fig.set_size_inches((15, 5))
fig.suptitle("Plink GWAS Manhattan and QQ Plot", fontsize=16)
qqman.manhattan(plink, ax=ax0)
qqman.qqplot(plink, ax=ax1)

# %% [markdown]
# ### GWAS in Python Manhattan and QQ Plot

# %%
gwas_py = pd.read_csv("../python_results/gwas_results_covar.tsv", sep=r"\s+")
fig, (ax0, ax1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [2, 1]})
fig.set_size_inches((15, 5))
fig.suptitle("GWAS in Python Manhattan and QQ Plot", fontsize=16)
qqman.manhattan(gwas_py, ax=ax0)
qqman.qqplot(gwas_py, ax=ax1)

# %% [markdown]
# ### Effect Size Comparison

# %%
merged = plink.merge(gwas_py, on="SNP", suffixes=("_plink", "_gwas_py"))
merged[["BETA_plink", "BETA_gwas_py"]].corr()

plt.scatter(merged["BETA_plink"], merged["BETA_gwas_py"], s=10)
plt.xlabel("PLINK Beta")
plt.ylabel("GWAS in Python Beta")
plt.title("Effect Size Comparison")
plt.show()

# %% [markdown]
# ### P-Value Comparison

# %%
merged["logP_plink"] = -np.log10(merged["P_plink"])
merged["logP_gwas_py"]  = -np.log10(merged["P_gwas_py"])

plt.scatter(merged["logP_plink"], merged["logP_gwas_py"], s=10)
plt.xlabel("-log10 P (PLINK)")
plt.ylabel("-log10 P (Gwas in Python)")
plt.title("P-value Comparison")
plt.show()

# %%
merged["rank_plink"] = merged["P_plink"].rank(method="min")
merged["rank_gwas_py"]  = merged["P_gwas_py"].rank(method="min")

merged[["rank_plink", "rank_gwas_py"]].corr()

top_plink = set(plink.nsmallest(10, "P")["SNP"])
top_gwas_py  = set(gwas_py.nsmallest(10, "P")["SNP"])

print("Overlap in Top 10:", len(top_plink & top_gwas_py))
# Out:
# Overlap in Top 10: 10

# %%
summary = merged[[
    "SNP",
    "BETA_plink", "BETA_gwas_py",
    "P_plink", "P_gwas_py",
    "rank_plink", "rank_gwas_py"
]].sort_values("rank_plink").head(20)

summary
# Out:
#                SNP  BETA_plink  BETA_gwas_py       P_plink     P_gwas_py  \
# 302263  rs62117204      2.2320      2.232244  7.782000e-45  8.170536e-45
# 302266   rs4803750      1.9110      1.910680  2.122000e-34  2.294679e-34
# 302262   rs1531517      0.8782      0.878578  2.279000e-12  2.256419e-12
# 833754    rs507666     -0.8700     -0.873846  2.024000e-10  1.640214e-10
# 833752   rs2519093     -0.8700     -0.873846  2.024000e-10  1.640214e-10
# 833761    rs495828     -0.6946     -0.698511  3.333000e-08  2.730954e-08
# 833759    rs651007     -0.6946     -0.698511  3.333000e-08  2.730954e-08
# 833760    rs579459     -0.6946     -0.698511  3.333000e-08  2.730954e-08
# 759797    rs962040      0.6920      0.694285  1.900000e-07  1.736315e-07
# 588158   rs3804100      0.8599      0.861290  4.352000e-07  4.194258e-07
# 537173    rs358702     -0.5098     -0.508348  1.800000e-06  1.941171e-06
# 659637  rs12216125      0.6093      0.614588  2.448000e-06  2.103206e-06
# 20706   rs12218029      0.9119      0.910122  2.464000e-06  2.608917e-06
# 113065  rs10862450      0.4962      0.494670  2.852000e-06  3.074221e-06
# 659611   rs1436307      0.4865      0.491033  2.994000e-06  2.411465e-06
# 659612   rs9358896      0.4865      0.491033  2.994000e-06  2.411465e-06
# 659615   rs1436306      0.4740      0.478492  3.903000e-06  3.147031e-06
# 496419  rs17033143      0.9592      0.962712  5.182000e-06  5.018756e-06
# 556688    rs800460      0.4737      0.475377  6.933000e-06  6.529671e-06
# 358464   rs2808500      0.6134      0.611940  7.133000e-06  7.506433e-06
#
#         rank_plink  rank_gwas_py
# 302263         1.0           1.0
# 302266         2.0           2.0
# 302262         3.0           3.0
# 833754         4.0           4.0
# 833752         4.0           4.0
# 833761         6.0           6.0
# 833759         6.0           6.0
# 833760         6.0           6.0
# 759797         9.0           9.0
# 588158        10.0          10.0
# 537173        11.0          11.0
# 659637        12.0          12.0
# 20706         13.0          15.0
# 113065        14.0          16.0
# 659611        15.0          13.0
# 659612        15.0          13.0
# 659615        17.0          17.0
# 496419        18.0          18.0
# 556688        19.0          19.0
# 358464        20.0          20.0

# %%
print("Beta correlation:", merged["BETA_plink"].corr(merged["BETA_gwas_py"]))
# Out:
# Beta correlation: 0.9996944466354389

# %% [markdown]
# # Clumping Comparisons
